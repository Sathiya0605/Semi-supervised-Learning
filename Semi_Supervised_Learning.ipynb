# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# Generate a synthetic dataset
X, y = make_moons(n_samples=1000, noise=0.1, random_state=42)

# Split the dataset into labeled and unlabeled
X_labeled, X_unlabeled, y_labeled, _ = train_test_split(X, y, train_size=0.1, random_state=42)

# Create a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train on labeled data first
model.fit(X_labeled, y_labeled, epochs=50, verbose=1)

# Use the model to predict labels for unlabeled data
y_pred_unlabeled = model.predict(X_unlabeled)
y_pred_unlabeled = (y_pred_unlabeled > 0.5).astype(int)

# Combine labeled and predicted unlabeled data
X_combined = np.vstack((X_labeled, X_unlabeled))
y_combined = np.hstack((y_labeled, y_pred_unlabeled.ravel())) #  Use ravel() to flatten y_pred_unlabeled into a 1D array
# Retrain the model with combined data
model.fit(X_combined, y_combined, epochs=50, verbose=1)

# Final evaluation (optionally on a separate test set)
loss, accuracy = model.evaluate(X_combined, y_combined)
print(f"final accuracy",{accuracy})
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3540 - loss: 0.7526
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3011 - loss: 0.7463
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3410 - loss: 0.7447
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3796 - loss: 0.7303
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4190 - loss: 0.7241
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4680 - loss: 0.7147
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5587 - loss: 0.7055
# Epoch 8/50
# ...
